# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Raw_Data/geo_data/winery-lat-lng-final.csv"
winery_geo_df = pd.read_csv(csv_file)
winery_geo_df.head(100)
# Out:
#                       winery   latitude   longitude
# 0                    Nicosia  35.185566   33.382276
# 1        Quinta dos Avidagos  41.387690   -7.276865
# 2                  Rainstorm  40.089829  -88.248177
# 3                 St. Julian  40.015971 -105.282767
# 4               Sweet Cheeks  42.343904  -71.101100
# 5                     Tandem  36.358159  -94.213735
# 6            Terre di Giurfo  37.111291   14.632700
# 7                   Trimbach  48.194905    7.326016
# 8         Jean-Baptiste Adam  48.126568    7.283714
# 9         Kirkland Signature  47.681243 -122.181894
# 10                Leon Beyer  48.042547    7.306562
# 11          Louis M. Martini  38.491074 -122.452179
# 12       Masseria Setteporte  38.909701  -76.999219
# 13                  Mirassou  25.943284  -80.296723
# 14           Richard Böcking  49.947177    7.112136
# 15                  Pradorey  41.703093   -3.790284
# 16               Quiévremont  49.703758    0.759117
# 17                   Acrobat  30.243192  -97.736861
# 18        Baglio di Pianetto  37.988126   13.349254
# 19                   Bianchi  37.654419 -122.141173
# 20                 Canicattì  37.358178   13.850690
# 21       Castello di Amorosa  38.558417 -122.542601
# 22   Clarksburg Wine Company  38.422495 -121.532457
# 23      Domaine de la Madone  46.197634    4.684787
# 24                   Envolve  27.994282  -82.546990
# 25                     Erath  29.958261  -92.035956
# 26                   Estampa  34.238601 -118.571543
# 27       Feudi del Pisciotto  37.115450   14.411940
# 28      Feudi di San Marzano  40.460951   17.496714
# 29             Feudo Montoni  38.148438   13.336047
# ..                       ...        ...         ...
# 70                  Palencia  30.026159  -81.385626
# 71             Poggio Alloro  43.487718   11.065163
# 72            Fattoria Sardi  43.876385   10.503534
# 73            Ferrari-Carano  38.711393 -122.978297
# 74              Folie à Deux  38.421283 -122.390024
# 75                Franciscan  36.088094  -95.785133
# 76                     Fuchs  39.061514  -94.784029
# 77                      Gård  46.995032 -120.547456
# 78                Heron Hill  42.449624  -77.201392
# 79          Soquel Vineyards  37.029516 -121.933867
# 80                   Ventosa  42.857164  -76.936131
# 81         Lamoreaux Landing  42.576632  -76.858453
# 82                     Leyda -33.613157  -71.450184
# 83         Marchesi Antinori  38.433166 -122.289791
# 84  Marchesi de' Frescobaldi  40.905533  -74.402750
# 85              Martin Ranch  37.040295 -121.711400
# 86                 Ornellaia  38.225892 -122.263705
# 87            Pardon et Fils  46.147659    4.598066
# 88                      Piña  38.467140 -122.377318
# 89              Podere Ciona  43.476413   11.456984
# 90             Poggioventoso  42.906522   10.968290
# 91                      Pull  36.220953  -95.877007
# 92                        R2  27.967495  -82.751513
# 93                    Rideau  45.425161  -75.691270
# 94            Tenuta Forconi  43.696166   10.989761
# 95             Dopff & Irion  48.166199    7.304255
# 96                   Ceretto  32.776382 -117.060575
# 97                    Matrix  36.096837  -95.918729
# 98                 Mauritson  38.650488 -122.912031
# 99   Henry's Drive Vignerons -34.982414  138.733575
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Connect to local database

# %%
conn_string = "mysql://root:FlyFly99!@localhost:3306/winery_db"
engine = create_engine(conn_string)

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['coordinates']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
winery_geo_df.to_sql(name='coordinates', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1366, "Incorrect string value: '\\xC4\\x87' for column 'winery' at row 3040")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-11-796c0eb43f64> in <module>
# ----> 1 winery_geo_df.to_sql(name='coordinates', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     232                 sql += b','
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#     236         return rows
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# ~\Anaconda3\envs\my_environment\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1366, "Incorrect string value: '\\xC4\\x87' for column 'winery' at row 3040") [SQL: 'INSERT INTO coordinates (winery, latitude, longitude) VALUES (%(winery)s, %(latitude)s, %(longitude)s)'] [parameters: ({'winery': 'Nicosia', 'latitude': 35.1855659, 'longitude': 33.382276399999995}, {'winery': 'Quinta dos Avidagos', 'latitude': 41.3876897, 'longitude': -7.2768652000000005}, {'winery': 'Rainstorm', 'latitude': 40.08982879999999, 'longitude': -88.2481766}, {'winery': 'St. Julian', 'latitude': 40.015970700000004, 'longitude': -105.2827672}, {'winery': 'Sweet Cheeks', 'latitude': 42.34390379999999, 'longitude': -71.1010995}, {'winery': 'Tandem', 'latitude': 36.3581585, 'longitude': -94.2137345}, {'winery': 'Terre di Giurfo', 'latitude': 37.1112907, 'longitude': 14.632699599999999}, {'winery': 'Trimbach', 'latitude': 48.1949046, 'longitude': 7.326016}  ... displaying 10 of 14094 total bound parameter sets ...  {'winery': 'El Furioso', 'latitude': 45.278981, 'longitude': -123.033569}, {'winery': 'Cuboid', 'latitude': 37.3377315, 'longitude': -121.894176})] (Background on this error at: http://sqlalche.me/e/2j85)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()
